# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('zameen.csv')
df.head()
# Out:
#                                            page_link  \
# 0  https://www.zameen.com/Property/islamabad_d_12...
# 1  https://www.zameen.com/Property/islamabad_d_12...
# 2  https://www.zameen.com/Property/islamabad_d_12...
# 3  https://www.zameen.com/Property/d_12_d_12_1_pr...
# 4  https://www.zameen.com/Property/d_12_d_12_1_br...
#
#                                             img_link  \
# 0  https://media.zameen.com/thumbnails/146451959-...
# 1  https://media.zameen.com/thumbnails/148842027-...
# 2  https://images.zameen.com/smap/400/300/33.7016...
# 3  https://media.zameen.com/thumbnails/148688704-...
# 4  https://media.zameen.com/thumbnails/149473249-...
#
#                                        whatsapp_link       price  \
# 0  https://wa.me/?text=1%20Kanal%20Brand%20New%20...  13.5 Crore
# 1  https://wa.me/?text=4%20Marla%20Prime%20locati...  3.25 Crore
# 2  https://wa.me/?text=Main%20Road%20Brand%20New%...   3.1 Crore
# ...

# %%
df.columns
# Out:
# Index(['page_link', 'img_link', 'whatsapp_link', 'price', 'location',
#        'bedrooms', 'bathrooms', 'area', 'title', 'description', 'time'],
#       dtype='object')
