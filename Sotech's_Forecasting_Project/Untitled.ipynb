# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_json('18206786-dataset1.json')

# %%
df.head()
# Out:
#      id                  name        born  \
# 0   541          Bette Midler  1945-12-01
# 1  1667  Jonathan Rhys Meyers  1977-07-27
# 2  5109            Mila Kunis  1983-08-14
# 3   133           Geena Davis  1956-01-21
# 4   213          Winona Ryder  1971-10-29
#
#                                               movies
# 0  [{'id': '11125620', 'title': 'The Addams Famil...
# 1  [{'id': '7975192', 'title': 'Hide and Seek', '...
# 2  [{'id': '7737640', 'title': 'Breaking News in ...
# 3  [{'id': '8784956', 'title': 'Ava', 'year': 202...
# 4  [{'id': '14018268', 'title': 'Cadillac: How Do...

# %%
import json

# %%
def jsonParse(filename):
    #Reading jsonfile
    f = open(filename,)
    act_ids=[]
    names=[]
    borns=[]
    movie_ids=[]
    titles=[]
    years=[]
    kinds=[]
    
    for dt in data:
        for df in dt['movies']:
            try:

                actor_id=dt['id']
                actor_name=dt['name']
                actor_dob=dt['born']



                mov_id=df['id']
                mov_title=df['title']
                mov_year=df['year']
                mov_kind=df['kind']

                act_ids.append(actor_id)
                names.append(actor_name)
                borns.append(actor_dob)
                movie_ids.append(mov_id)
                titles.append(mov_title)
                years.append(mov_year)
                kinds.append(mov_kind)
            except:
                pass
    
    
    
    my_dict={"actor_id":act_ids,
        "actor_name":names,
        "actor_dob":borns,
        "movie_id":movie_ids,
        "movie_titel":titles,
        "movie_year":years,
        "movie_kind":kinds}
    
    
    dfn=pd.DataFrame(my_dict)
    return dfn

# %%
jsonParse('18206786-dataset1.json')
# Out:
#      actor_id    actor_name   actor_dob  movie_id  \
# 0     0000541  Bette Midler  1945-12-01  11125620
# 1     0000541  Bette Midler  1945-12-01   7435316
# 2     0000541  Bette Midler  1945-12-01   1620981
# 3     0000541  Bette Midler  1945-12-01   5089534
# 4     0000541  Bette Midler  1945-12-01   1047540
# ...       ...           ...         ...       ...
# 9423  0574534   Ian McShane  1942-09-29   0078601
# 9424  0574534   Ian McShane  1942-09-29   0075526
# 9425  0574534   Ian McShane  1942-09-29   0075520
# 9426  0574534   Ian McShane  1942-09-29   0075572
# 9427  0574534   Ian McShane  1942-09-29   0073213
#
#                            movie_titel  movie_year movie_kind
# 0                  The Addams Family 2        2021      movie
# 1                          The Glorias        2020      movie
# 2                    The Addams Family        2019      movie
# 3                           Freak Show        2017      movie
# ...

# %%
data = json.load(f)

# %%
act_ids=[]
names=[]
borns=[]
movie_ids=[]
titles=[]
years=[]
kinds=[]

for dt in data:
    for df in dt['movies']:
        try:
            
            actor_id=dt['id']
            actor_name=dt['name']
            actor_dob=dt['born']

            

            mov_id=df['id']
            mov_title=df['title']
            mov_year=df['year']
            mov_kind=df['kind']

            act_ids.append(actor_id)
            names.append(actor_name)
            borns.append(actor_dob)
            movie_ids.append(mov_id)
            titles.append(mov_title)
            years.append(mov_year)
            kinds.append(mov_kind)
        except:
            pass

# %%
print(len(act_ids))
print(len(names))
print(len(borns))
print(len(movie_ids))
print(len(titles))
print(len(years))
print(len(kinds))
# Out:
# 9428
# 9428
# 9428
# 9428
# 9428
# 9428
# 9428

# %%
my_dict={"actor_id":act_ids,
        "actor_name":names,
        "actor_dob":borns,
        "movie_id":movie_ids,
        "movie_titel":titles,
        "movie_year":years,
        "movie_kind":kinds}

# %%
dfn=pd.DataFrame(my_dict)

# %%
dfn.head()
# Out:
#   actor_id    actor_name   actor_dob  movie_id          movie_titel  \
# 0  0000541  Bette Midler  1945-12-01  11125620  The Addams Family 2
# 1  0000541  Bette Midler  1945-12-01   7435316          The Glorias
# 2  0000541  Bette Midler  1945-12-01   1620981    The Addams Family
# 3  0000541  Bette Midler  1945-12-01   5089534           Freak Show
# 4  0000541  Bette Midler  1945-12-01   1047540    Parental Guidance
#
#    movie_year movie_kind
# 0        2021      movie
# 1        2020      movie
# 2        2019      movie
# 3        2017      movie
# 4        2012      movie
